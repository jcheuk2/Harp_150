# %%
import matplotlib.pyplot as plt  # pyplot is a module within matplotlib library to create plots

# %% [markdown]
# **look here for the modeule** https://matplotlib.org/3.5.3/api/_as_gen/matplotlib.pyplot.html

# %% [markdown]
# Basic Line graph

# %%
x = [0,1,2,3,4,5,6,20]
y = [2,4,6,8,10,12,14,18]

plt.plot(x,y)

plt.show()

# %%
### must remember to calculate the figure size
plt.figure(figsize = (10,10), dpi = 300)
# dpi = dots per inch, and it shows allows you to show the amount of pixels you want your graph to have

# choose whether or not to have a grid
plt.grid()
# list of data in terms of x and y
x = [0,1,2,3,4,5,6]
y = [0,2,4,6,8,10,12]
# label graph
plt.title("our very first graph")
# lavel x axis and y axis
plt.xlabel("x axis")
plt.ylabel("y axis")
# label ticks
custon_xticks = range(0,21,2)
plt.xticks(custon_xticks)
#
plt.plot(x,y)
#

# this allows you to save it on google drive? of on your computer.
# in colab it saves in the local files of the .py
# HOW DO YOU SAVE IT PERMANENT
# YOU HAVE TO MANUALLY DOWNLOAD IT ON YOUR COMPUTER AFTER IT'S ON THE FILES PAGE ON COLAB
# very important to have the name.{file type here}
plt.savefig("our very first graph.jpeg")


# you don' tneed to memorize a lot of the methods
#
plt.show()

# %% [markdown]
# * You don't need to memorize anything. You just need to know how the syntax is
