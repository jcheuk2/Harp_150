# %%
#if you run into misunderstandings in the labs, you should go to the table of contents to find what parts you do or don't understand.
#

# What have we learned so far?
# What are we struggling with?

# we've learned variables and data structures
# some variables include booleans, strings,
# lists, loops, tuples, sets
# Sets don't repeat, order is random
# tuples, you can't cahnge a tuple
# if you have data you don't want to be changed, you use a tuple.
# conditionals



# functions
 through the code and test it out & elements you recognize or do not recognize

# %% [markdown]
# He rkaraoke song list
#
#
#
# * Look through the code & test it out & elements you recognize or do not recognize
# * What can we do with the program we built? - HARP151
# * Design choices & targeted users
# * How can we improve the program? - expand the program

# %% [markdown]
# More on functions: how to call a function within a function

# %%
def addition (num1,num2):
  return num1+num2
# a = addition(4,6)
print(nyum1)

# def do_math(num1,num2):

#   total = num1+num2
#   total = addition(num1,num2)
#   return total

# do_math(4,6)
# Out:
# 10

# %%
def addition (num1,num2):
  return num1+num2
  global num1
a = addition(4,6)
print(num1)

# def do_math(num1,num2):

#   total = num1+num2
#   total = addition(num1,num2)
#   return total

# do_math(4,6)

# you cannot print num1 becauese num1 only exists within the
# to make num 1 to be printable outside of the
# Out:
#   File "<ipython-input-7-72ac2b2ee381>", line 3
#     global num1
#     ^
# SyntaxError: name 'num1' is parameter and global

# %% [markdown]
# Local scope and global scope:
#
#
#
# *   List item
# *   List item

# %% [markdown]
# # default arguemtn and keyworkd argument

# %%
# default arguemtn and keyworkd argument
def greetings(name, greeting ="hello"):
  # "hellp is the default arguemtn for greeting parameter"
  print(f'{greeting},{name}!')

#do not chaneg default argument
greetings("alice")

#changing default argument
greetings("bill","good morning!")

#name and greeting are the keyworkds we can reference
greetings(greeting = "have a good day", name = "carla")
# Out:
# hello,alice!
# good morning!,bill!
# have a good day,carla!

# %% [markdown]
# The post-lab exercises are getting more complex now
# => turn in a partially finished homework is better than plagiarism & use the 24 hour late labs buffer
# => attend office & tutoring hours & ask for extensions
#
#
# *   extensions before the deadline are gifted if asked beforehand
# *   List item

# %% [markdown]
# Check Game Project (proposal - made some changes & code) + Presentation instructions on pg. 14-16 on syllabus

# %% [markdown]
# We’re going to look at some code for simple Python games.
#
# DO NOT PLAGIARIZE THESE for your game project!!

# %% [markdown]
# https://github.com/Ninedeadeyes/15-mini-python-games-tutorial-series

# %%
# joanna Fishman

# she won a hackathon

# hakcathon

# taking systems that are in place to better them or redfeine them

#https://hackbu.org/

# has a lot of resources that show you about

# tam of four: Jason, Ken, Joanna, Andrew


# binghamton codes: is a program in dida minor

# she is a film major

# I think you should talk to her because she wanted to make a project that made it easier for people
# to naviage capus

# How is this relevant to Harp 150?
# a topic that was heavily emphasized through this project was accessing something similar to dictionaries.
#JSON files are formattred basically identiclaly to dictioonaries and accessing them in JavaScript is veryt
# similar to accessing them in python.
# that is basically what our "backend" was to our website, despite it being a static website.


# https://github.com/kenyounot123/BU-hackathon

# demo
# hyyps://kenyounot123.github.io/BU-hackathon/

# I have a question, how did you learn skills outside of the class?
# did you learn about it outside of class? did you learn the skill outside of clas?
