# %%
# you must have comments in your game lab
#

# %% [markdown]
# * It’s best to THINK a lot before you start programming
# * Identify all the things you think your program will need to do to run successfully – write them down or map them out
# * Don’t be afraid to write “ugly” code - you can always streamline it later
# * Don’t be afraid to TRY things, you can’t hurt the
#
# *   List item
# *   List item
#
# computer!
