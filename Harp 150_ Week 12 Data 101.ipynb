# %% [markdown]
# * use a CSV file or an excel file to work with data
# * Use the data in the sports
# * Make sure you get the data analysis
# * find bigger data sets.
# * you will defeat the purpose of using code to use the dataset
# * what does she mean by big, use over 10,000 rows of data.
# * Spreadsheet Software (excel, google sheet)
# * Point and click
# * Easier to learn
# * Great for small datasets (<10,000 rows)
# * Better for browsing data
#
# * Pandas
# * More powerful data manipulation with Python
# * Can work with large datasets (millions of rows)
# * Faster for complicated manipulations
# * Better for cleaning and/or pre-processing data
# * Can automate workflows in a larger data pi
# * For the data project, the actual data analysis has to be done through code
# * Depending on the sport

# %% [markdown]
# https://docs.google.com/presentation/d/1h4N5JhDTS8LF2EY4utJniSCch6P9jJYqh4wRjHXlqWI/edit?usp=sharing

# %% [markdown]
# *   Data analysis is typically driven by one or more research questions
# * To analyze, you need to explore what the data can “tell” you – this requires cleaning it and getting read of outliers that can bias your results
# * Types of analysis:
#   * Diagnostic (Why did x happen?)
#   * Predictive (What will probably happen?)
#   * Prescriptive (What should you do next?)
#   * Statistical (What happened?)
#   * Dana mining (Examines vast quantities of text data)
#  * Let’s look at an example from Github called “Trucks and Beer”
# *

# %% [markdown]
# Advantages of using python for coding:
#
# * Access data (like APIs, webscrapping, and your own datasets)
# * clean data - process of identify and correcting inaccuratne and corrupt data
# * visualize data - Creating visuals / graphics of your data
# * Analyze data - a process that can include data cleaning and visualizatio, allowing you to learn from the data
# * Create Data - you can use python to create files
#
# * may have scraping bots.
