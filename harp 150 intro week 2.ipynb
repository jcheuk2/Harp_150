# %%
print("hello world")
# here's how the pring function works
# how do you do markdown in google colab? Jupyter notebook isn't working for me.
# Out:
# hello world

# %% [markdown]
# # Title 1 #
#
# ##Title 2##
#
# ### Title 3 ###

# %%
print("I hate snow!")
# print() Function
# "" - words/sentences
" Here is the instructions for this function "
# Out:
# I hate snow!
# ' Here is the instructions for this function '

# %%
print("fall is the best")
# Out:
# fall is the best

# %%
# what are the 3 different types of comments?

# %%
# she did say tyhat why the jupyter notebook is different from ours.
# her's has the numbers next to the line of code.
# find which line of code has a problem
# Ctrl + Z to undo the code
# the cell runs all together, so separate you code based on the
# injupyter, you can hover over insert and inset coding cell above or coding cell below
# shift + enter allows you to create new cells
# sometimes, your jupyter notebook might freeze. to solve this you click on Kernel and you press
# a kernel is an enginge for the jupyter notebook. it is what the
# when kernel presses interrupt, it stops everything.
# when you run code cells, the cells will have an asterik when it is running.
# interrupt the kernel
# under kernel if you put cancel output under kernel, your code will still be there, but the output won't be there.

# %%
# how to open a file in jupyter notebook
# you click upload
# you need to upload .jpynb file in JN.
# if you press file, download as, and press .jpynb, you will download it

# %%
# how to save jupyter notebook into google drive
# link google drive command line code.

# %%
# how do you find command line bu taking harp 150.
# google colab and jupyter is pretty much the same.
# differences being rutime = kernel
# difference is that the folder on the top left hand corner is the button to upload files. in jupyter notebook, to upload file you press file and file upload
#
